# %%
print("hello word")
# Out:
# hello word

# %%
#lists
L=["waleed ",1233,1.49,('a',1)]
print(L[0])
print(L[1])
print(L[2])
print(L[3])
# Out:
# waleed
# 1233
# 1.49
# ('a', 1)

# %%
L=["waleed ",1233,1.49,('a',1)]
print(L[-4])
print(L[-3])
print(L[-2])
print(L[-1])
# Out:
# waleed
# 1233
# 1.49
# ('a', 1)

# %%
#list slicing
L=["waleed ",1233,1.49,('a',1)]
print(L[1:2])
print(L[3:4])
# Out:
# [1233]
# [('a', 1)]

# %%
#list adding
L=["waleed ",1233,1.49,('a',1)]
L1=L+["ahmed",12]
print(L1)
# Out:
# ['waleed ', 1233, 1.49, ('a', 1), 'ahmed', 12]

# %%
L=["waleed ",1233,1.49,('a',1)]
L.extend(["wahab",2.3])
print(L)
# Out:
# ['waleed ', 1233, 1.49, ('a', 1), 'wahab', 2.3]

# %%
L=["waleed ",1233,1.49,('a',1)]
L.append(["wahab",2.3])
print(L)
# Out:
# ['waleed ', 1233, 1.49, ('a', 1), ['wahab', 2.3]]

# %%
L=["waleed ",1233,1.49,('a',1)]
L[0]="ali"
print(L)
# Out:
# ['ali', 1233, 1.49, ('a', 1)]

# %%
L=["waleed ",1233,1.49,('a',1)]
del(L[2])
print(L)
# Out:
# ['waleed ', 1233, ('a', 1)]

# %%
L="may you live long"
c=L[:]
print(c)
print(L)
# Out:
# may you live long
# may you live long

# %%
#converting a sting into list

L=L.split(",")
print(L)

L="may you long"
L.split()
print(L)
# Out:
# ['may you long']
# may you long

# %%
L="may you live long"
help(L)
# Out:
# No Python documentation found for 'may you live long'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
L = ["may", "you", "live", "long"]
c = L      # aliasing

L[0] = "weee"
c[1] = "errr"

print(L)
print(c)
L = ["may", "you", "live", "long"]
c = L      # aliasing

L[0] = "weee"
c[0] = "errr"

print(L)
print(c)
# Out:
# ['weee', 'errr', 'live', 'long']
# ['weee', 'errr', 'live', 'long']
# ['errr', 'you', 'live', 'long']
# ['errr', 'you', 'live', 'long']
